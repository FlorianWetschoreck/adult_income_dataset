# %%
import bamboolib as bam

# %%
bam.enable()
# Out:
# Success: the bamboolib extension was enabled successfully. You can disable it via 'bam.disable()'. You will now see a magic bamboolib button when you display your dataframes, for example via 'df'

# %%
import pandas as pd

# %%
df = pd.read_csv("data/adults.csv")

# %%
df
# Out:
#       age          workclass      education  Education-num        occupation  \
# 0      44          Local-gov        HS-grad              9   Protective-serv
# 1      66   Self-emp-not-inc        7th-8th              4   Farming-fishing
# 2      25            Private     Assoc-acdm             12      Tech-support
# 3      20                NaN   Some-college             10               NaN
# 4      26            Private   Some-college             10             Sales
# ...   ...                ...            ...            ...               ...
# 4995   51            Private        HS-grad              9      Craft-repair
# 4996   39            Private      Assoc-voc             11      Craft-repair
# 4997   65            Private        HS-grad              9   Farming-fishing
# 4998   37       Self-emp-inc      Assoc-voc             11             Sales
# 4999   42            Private        HS-grad              9   Exec-managerial
#
# ...
